# %% [markdown]
# ## Importing Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading Excel File

# %%
dataset=pd.read_excel('Win_Prediction_Data.xlsx')
dataset.head()
# Out:
#   Client Category Solution Type  Deal Date     Sector Location      VP Name  \
# 0         Telecom    Solution 7 2012-03-27  Sector 24       L5  Ekta Zutshi
# 1         Telecom    Solution 7 2012-09-25  Sector 24       L5  Ekta Zutshi
# 2        Internal   Solution 59 2011-08-01  Sector 20   Others  Ekta Zutshi
# 3        Internal   Solution 59 2011-04-28  Sector 20   Others  Ekta Zutshi
# 4        Internal   Solution 32 2011-06-03  Sector 20   Others  Ekta Zutshi
#
#       Manager Name  Deal Cost Deal Status Code
# 0  Gopa Trilochana  150000.00              Won
# 1  Gopa Trilochana  744705.88              Won
# 2   Russell Dahlen   60000.00             Lost
# 3   Russell Dahlen   60000.00             Lost
# 4   Russell Dahlen   80882.35             Lost

# %%
df=dataset.copy() ## creating dataset copy

# %%
df.shape
# Out:
# (10061, 9)

# %%
df.tail(50)
# Out:
#             Client Category Solution Type  Deal Date     Sector Location  \
# 10011        Infrastructure    Solution 6 2019-01-13  Sector 11       L6
# 10012         Consumer Good   Solution 67 2019-03-13  Sector 18      L10
# 10013             Power ind    Solution 9 2019-01-27   Sector 9       L5
# 10014              Internal   Solution 29 2019-04-21   Sector 2   Others
# 10015               Finance   Solution 31 2019-04-21   Sector 2       L5
# 10016                Others    Solution 9 2019-01-14  Sector 18      L10
# 10017               Finance    Solution 9 2019-02-26   Sector 2       L4
# 10018        Services_based    Solution 9 2019-01-23  Sector 13       L5
# 10019             Power ind   Solution 39 2019-05-06   Sector 9       L5
# 10020             Insurance    Solution 9 2019-04-07  Sector 16       L5
# 10021             Insurance    Solution 9 2019-01-20  Sector 16       L5
# 10022         Domestic Bank    Solution 9 2019-02-24  Sector 16       L1
# 10023    International Bank   Solution 67 2019-04-01   Sector 2      L10
# 10024        Infrastructure   Solution 67 2019-05-14   Sector 9      L10
# 10025        Infrastructure    Solution 6 2019-04-07  Sector 11       L6
# 10026             Insurance    Solution 9 2019-02-12  Sector 16      L10
# 10027     Govt Bank Special   Solution 32 2019-03-27  Sector 17      L10
# 10028             Power ind    Solution 9 2019-02-25   Sector 9       L5
# 10029           Automobiles    Solution 9 2019-01-11   Sector 1       L3
# 10030     Govt Bank Special   Solution 32 2019-01-31  Sector 17      L10
# 10031                  Tech    Solution 9 2019-03-20  Sector 22       L5
# 10032  Domestic Public Bank    Solution 9 2018-11-28   Sector 2      L10
# 10033     Govt Bank Special    Solution 9 2019-03-02   Sector 2      L10
# 10034             Power ind    Solution 9 2019-01-12   Sector 9       L5
# 10035                Others    Solution 9 2018-12-03  Sector 12       L1
# 10036                  Tech    Solution 9 2019-02-01  Sector 22       L5
# 10037             Insurance    Solution 9 2019-04-18  Sector 16      L10
# 10038        Services_based    Solution 9 2019-03-19  Sector 23       L1
# 10039    International Bank    Solution 9 2018-12-05  Sector 17      L10
# 10040         Retail_market   Solution 58 2019-04-27  Sector 12       L5
# 10041        Services_based   Solution 49 2019-02-16  Sector 18       L1
# 10042                  Tech    Solution 2 2019-05-06  Sector 23       L5
# 10043                  Tech    Solution 4 2019-02-10  Sector 15       L5
# 10044             Insurance    Solution 9 2019-03-24  Sector 16       L5
# 10045                Others    Solution 9 2018-11-16  Sector 12      L10
# 10046    International Bank    Solution 9 2019-03-02  Sector 17      L10
# 10047              Internal   Solution 32 2019-03-20  Sector 23      L10
# 10048             Insurance    Solution 9 2019-04-20  Sector 16       L5
# 10049               Finance   Solution 37 2019-03-31  Sector 17      L10
# 10050                Others   Solution 32 2019-01-15  Sector 23       L4
# 10051             Power ind    Solution 4 2018-12-25   Sector 9       L5
# 10052               Telecom    Solution 9 2019-05-07  Sector 24      L10
# 10053             Power ind    Solution 9 2019-03-25   Sector 9       L5
# 10054               Telecom    Solution 4 2019-01-23  Sector 24       L5
# 10055               Telecom    Solution 9 2019-05-23  Sector 24      L10
# 10056             Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057              Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058             Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059             Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060                Others    Solution 9 2019-05-30  Sector 12      L10
#
#                    VP Name          Manager Name   Deal Cost Deal Status Code
# 10011       Russell Dahlen            Aman Gupta   382352.94             Lost
# 10012        Sarthak Batra          Naveen Dogra  1235294.12             Lost
# 10013          Man Suddeth           Jose Gamber  1382352.94              Won
# 10014      Sargar Deep Rao        Ranjan Prakash   204117.65              Won
# 10015         Clinton Mani          Rosana Yokum   235294.12              Won
# 10016       Russell Dahlen           Tanu Panwar   144117.65              Won
# 10017        Saurabh Singh  Devendra Vishvakarma   461764.71             Lost
# 10018          Vidur Hukle           mohd shakib  1882352.94             Lost
# 10019          Molly Eakes         mohd ataullah  1058823.53              Won
# 10020       Mervin Harwood       Sanchita Gulati   220588.24              Won
# 10021       Mervin Harwood       Sanchita Gulati   220588.24              Won
# 10022          Man Suddeth         Virak Kandpal   502941.18              Won
# 10023  Kamelesh Srinivasan            jamil khan   235294.12             Lost
# 10024       Russell Dahlen          sheak shakir   882352.94              Won
# 10025       Russell Dahlen            Aman Gupta   382352.94             Lost
# 10026       Mervin Harwood        ram dutt gupta   176470.59             Lost
# 10027       Long Bergstrom        Navita Chauhan   426470.59             Lost
# 10028          Man Suddeth       Mannan Upadhiya  1122058.82             Lost
# 10029      Ankita Aggarwal       bhagwati prasad   424705.88              Won
# 10030       Long Bergstrom        Navita Chauhan   426470.59             Lost
# 10031      Gopa Trilochana       Darla Dickinson   352941.18             Lost
# 10032       Mervin Harwood          Rosana Yokum    72941.18              Won
# 10033       Manpreet Singh       Darla Dickinson   733529.41             Lost
# 10034          Man Suddeth       Mannan Upadhiya  1122058.82             Lost
# 10035       Hardeep Suksma             ram kumar   213235.29              Won
# 10036      Gopa Trilochana       Darla Dickinson   352941.18             Lost
# 10037       Mervin Harwood        ram dutt gupta   176470.59             Lost
# 10038      Ankita Aggarwal             Uzaar Ali   529411.77              Won
# 10039       Russell Dahlen         Akshit Khanna   383823.53             Lost
# 10040         Rahul Kocher       maansingh aswal   276470.59              Won
# 10041        Saurabh Singh           Waseem Khan   147058.82              Won
# 10042      Earline Langton           Neha Sharma   102941.18              Won
# 10043      Rudraksh Sharma        Abhiskek Kumar    73529.41              Won
# 10044      Gopa Trilochana             Amit Jain   701470.59             Lost
# 10045      Son Mcconnaughy            Tarun Garg   147058.82             Lost
# 10046       Russell Dahlen         Akshit Khanna   383823.53             Lost
# 10047   Jitendra Choudhary          ramdin verma    55000.00              Won
# 10048      Gopa Trilochana             Amit Jain   701470.59             Lost
# 10049         Clinton Mani          Sangeet Daga   470588.24              Won
# 10050         Gayle Molter        Rayford Durgan   882352.94              Won
# 10051            Alam Syed         Rateesh Singh  1404411.77              Won
# 10052      Gopa Trilochana       Darla Dickinson   823529.41             Lost
# 10053          Man Suddeth           Jose Gamber  3462058.82              Won
# 10054         Rahul Bajpai        Abhiskek Kumar    58823.53              Won
# 10055      Gopa Trilochana       Darla Dickinson   823529.41             Lost
# 10056      Rudraksh Sharma       Rudraksh Sharma   588235.29             Lost
# 10057      Rudraksh Sharma        Sharavan Singh   777058.82              Won
# 10058      Rudraksh Sharma       Rudraksh Sharma   588235.29             Lost
# 10059          Man Suddeth       Cleotilde Biron  3042058.82              Won
# 10060      Son Mcconnaughy            Tarun Garg   147058.82             Lost

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10061 entries, 0 to 10060
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Client Category   9982 non-null   object
#  1   Solution Type     10061 non-null  object
#  2   Deal Date         10061 non-null  datetime64[ns]
#  3   Sector            10061 non-null  object
#  4   Location          10061 non-null  object
#  5   VP Name           10061 non-null  object
#  6   Manager Name      10061 non-null  object
#  7   Deal Cost         10061 non-null  float64
#  8   Deal Status Code  10061 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 707.5+ KB

# %% [markdown]
# ## Summary of Numerical Variable

# %%
df.describe()
# Out:
#           Deal Cost
# count  1.006100e+04
# mean   7.668969e+05
# std    1.619894e+06
# min    0.000000e+00
# 25%    1.897059e+05
# 50%    3.823529e+05
# 75%    7.647059e+05
# max    3.676471e+07

# %% [markdown]
# ## Summary of Categorical Variable

# %%
df.describe(include='O')
# Out:
#        Client Category Solution Type     Sector Location         VP Name  \
# count             9982         10061      10061    10061           10061
# unique              41            67         25       13              43
# top             Others   Solution 32  Sector 23      L10  Mervin Harwood
# freq              1763          1439       2693     3360            1166
#
#        Manager Name Deal Status Code
# count         10061            10061
# unique          278                2
# top     Molly Eakes             Lost
# freq            323             6306

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# ### Null Value Check

# %%
df.isnull().sum() * 100 / len(df) #Only 'Client Category' has null values that is 0.78521%
# Out:
# Client Category     0.78521
# Solution Type       0.00000
# Deal Date           0.00000
# Sector              0.00000
# Location            0.00000
# VP Name             0.00000
# Manager Name        0.00000
# Deal Cost           0.00000
# Deal Status Code    0.00000
# dtype: float64

# %%
Client_Category = df['Client Category'].value_counts()

# %%
Client_Category
# Out:
# Others                   1763
# Internal                 1454
# Services_based           1202
# Tech                      913
# Domestic Public Bank      419
# International Bank        376
# Consulting                352
# Finance                   339
# Telecom                   327
# Power ind                 264
# Domestic Private Bank     262
# Insurance                 247
# Consumer Good             185
# Automobiles               178
# Infrastructure            152
# Domestic Bank             134
# Retail_market             126
# Govt                      121
# Hospitality               119
# Manufacturing             117
# Pharma                    110
# Healthcare                 99
# Electronics                81
# Media_Journal              71
# Industries                 66
# Research Development       63
# Energy                     57
# Knowledge                  50
# Management                 43
# Govt Bank Special          41
# Payment                    40
# Energy                     37
# e-commerce                 32
# Airpline                   27
# Holding                    25
# International Org          25
# Logistics                  20
# Real Estate                19
# Share_market               14
# Tax_audit                   7
# Medical                     5
# Name: Client Category, dtype: int64

# %% [markdown]
# ### Replacing Null Values in Client Category column with mode value

# %%
df['Client Category'] = df['Client Category'].fillna('Others')

# %%
df.isnull().sum()
# Out:
# Client Category     0
# Solution Type       0
# Deal Date           0
# Sector              0
# Location            0
# VP Name             0
# Manager Name        0
# Deal Cost           0
# Deal Status Code    0
# dtype: int64

# %%
df.nunique() #No column have single unique value
# Out:
# Client Category       41
# Solution Type         67
# Deal Date           2555
# Sector                25
# Location              13
# VP Name               43
# Manager Name         278
# Deal Cost           1469
# Deal Status Code       2
# dtype: int64

# %%
for i in df.columns:
    print(i,':',df[i].unique())
# Out:
# Client Category : ['Telecom' 'Internal' 'Govt' 'Consumer Good' 'International Bank'
#  'Domestic Public Bank' 'Finance' 'Manufacturing' 'Services_based'
#  'Research Development' 'Others' 'Hospitality' 'Consulting'
#  'Retail_market' 'Energy ' 'Domestic Private Bank' 'Industries' 'Tech'
#  'Healthcare' 'Electronics' 'Domestic Bank' 'Automobiles' 'Medical '
#  'Infrastructure' 'Pharma' 'Power ind' 'Holding' 'Logistics' 'Insurance'
#  'Payment' 'Energy' 'Govt Bank Special' 'Management' 'Media_Journal'
#  'International Org' 'Real Estate' 'Tax_audit' 'Share_market' 'Knowledge'
#  'Airpline' 'e-commerce']
# Solution Type : ['Solution 7' 'Solution 59' 'Solution 32' 'Solution 42' 'Solution 6'
#  'Solution 20' 'Solution 37' 'Solution 31' 'Solution 39' 'Solution 3'
#  'Solution 30' 'Solution 33' 'Solution 29' 'Solution 40' 'Solution 14'
#  'Solution 67' 'Solution 10' 'Solution 28' 'Solution 47' 'Solution 36'
#  'Solution 44' 'Solution 38' 'Solution 55' 'Solution 35' 'Solution 2'
#  'Solution 34' 'Solution 48' 'Solution 52' 'Solution 61' 'Solution 11'
#  'Solution 12' 'Solution 15' 'Solution 4' 'Solution 46' 'Solution 63'
#  'Solution 60' 'Solution 65' 'Solution 24' 'Solution 41' 'Solution 13'
#  'Solution 50' 'Solution 66' 'Solution 25' 'Solution 8' 'Solution 16'
#  'Solution 51' 'Solution 58' 'Solution 26' 'Solution 17' 'Solution 49'
#  'Solution 27' 'Solution 53' 'Solution 1' 'Solution 45' 'Solution 9'
#  'Solution 64' 'Solution 5' 'Solution 62' 'Solution 57' 'Solution 43'
#  'Solution 23' 'Solution 22' 'Solution 54' 'Solution 56' 'Solution 18'
#  'Solution 19' 'Solution 21']
# Deal Date : ['2012-03-27T00:00:00.000000000' '2012-09-25T00:00:00.000000000'
#  '2011-08-01T00:00:00.000000000' ... '2019-04-20T00:00:00.000000000'
#  '2019-05-23T00:00:00.000000000' '2019-05-30T00:00:00.000000000']
# Sector : ['Sector 24' 'Sector 20' 'Sector 2' 'Sector 13' 'Sector 12' 'Sector 15'
#  'Sector 17' 'Sector 23' 'Sector 14' 'Sector 22' 'Sector 9' 'Sector 16'
#  'Sector 25' 'Sector 1' 'Sector 4' 'Sector 18' 'Sector 3' 'Sector 6'
#  'Sector 21' 'Sector 8' 'Sector 11' 'Sector 19' 'Sector 5' 'Sector 7'
#  'Sector 10']
# Location : ['L5' 'Others' 'L10' 'L11' 'L1' 'L4' 'L9' 'L3' 'L7' 'L6' 'L12' 'L2' 'L8']
# VP Name : ['Ekta Zutshi' 'Mervin\xa0Harwood' 'Sargar Deep Rao' 'Lilli\xa0Storrs'
#  'Long\xa0Bergstrom' 'Rosanna\xa0Maynez' 'Mangesh K. Singh'
#  'Brendon\xa0Wycoff' 'neeraj kumar' 'Rahul Bajpai' 'Son\xa0Mcconnaughy'
#  'Saurabh Singh' 'Rudraksh Sharma' 'Hardeep Suksma' 'Varsha Arora'
#  'som dutt' 'Ankita Aggarwal' 'Clinton\xa0Mani' 'Marcella\xa0Mo'
#  'Dennis\xa0Faux' 'Earline\xa0Langton' 'Russell\xa0Dahlen'
#  'Gopa Trilochana' 'Kamelesh Srinivasan' 'Gaurav Sameria' 'Manpreet Singh'
#  'Man\xa0Suddeth' 'Molly\xa0Eakes' 'Vidur Hukle' 'Gayle\xa0Molter'
#  'Alam Syed' 'Rahul Kocher' 'Vikram Rawat' 'Jewell\xa0Tunstall'
#  'Jitendra Choudhary' 'Mayank Mewar' 'Kirk\xa0Hofmeister' 'P. Somya'
#  'Prashant Rawat' 'Visvajeet Das' 'Waylon\xa0Mulder' 'Sarthak Batra'
#  'md. afsar']
# Manager Name : ['Gopa Trilochana' 'Russell\xa0Dahlen' 'rahul sharma' 'Vidur Hukle'
#  'Md. Daud' 'Hardeep Suksma' 'Luv Malhotra' 'Lino\xa0Batterton'
#  'Sang\xa0Ingle' 'shafibul' 'Anand S. Pandey' 'Molly\xa0Eakes'
#  'Prateek Dhotre' 'Roopal Singh' 'Desmond\xa0Krout' 'Jean\xa0Sappington'
#  'Mangesh K. Singh' 'Abhinav Warrier' 'Saurabh Singh' 'Tanuj Bindra'
#  'nahar singh' 'D. Ankit ' 'Muoi\xa0Queener' 'Ayusha Gupta'
#  'Rudraksh Sharma' 'Ekta Zutshi' 'Fredricka\xa0Bald' 'Ganesh Malwar'
#  'Kamelesh Srinivasan' 'Jewell\xa0Tunstall' 'Ankita Aggarwal'
#  'Somnath Mukherji' 'Tafeeq Khan' 'Rosana\xa0Yokum' 'Gaurav Sameria'
#  'Rahul Bajpai' 'Dennis\xa0Faux' 'Theron\xa0Rex' 'Shobhit Gupta'
#  'Marcella\xa0Mo' 'Rahul Kocher' 'Akshay Sharma' 'ram kumar'
#  'Sanchita Gulati' 'mohd shakib' 'Anoop Jatley' 'Ralph\xa0Bohon'
#  'mohd khairul' 'Akshansh Goel' 'Rajneesh Tanwar' 'Manpreet Singh'
#  'Chanchal sharma' 'Vinay Kumar' 'Elenor\xa0Halderman' 'Long\xa0Bergstrom'
#  'Karan Dubey' 'Subhangi Sood' 'Clinton\xa0Mani' 'Evangeline\xa0Kepley'
#  'Vikrant Saini' 'Gayle\xa0Molter' 'Neha Sharma' 'neeraj kumar'
#  'Jayadev Mitali' 'rijul aggarwal' 'Rahul Singh' 'Jitendra Choudhary'
#  'sunder paal' 'riyasat ali' 'Evalyn\xa0Rayner' 'Sooraj Vohra' 'vansu dev'
#  'David Toms' 'Eva\xa0Harte' 'Ankit Bhutani' 'Kizzie\xa0Troxel'
#  'Rosanna\xa0Maynez' 'Mannan Upadhiya' 'Nitish Bhardwaj' 'Abram\xa0Fines'
#  'Natalia\xa0Dumlao' 'Earline\xa0Langton' 'Sohil Kumar' 'Bhavya Saini'
#  'Lokesh Pinani' 'Marcelo\xa0Riles' 'mayank chaudhary @ rahul' 'som dutt'
#  'Carroll\xa0Truehart' 'Alam Syed' 'Akul Jindal' 'aamir hussain'
#  'Edmund\xa0Brigham' 'Annamaria\xa0Phung' 'Varsha Arora' 'Sargar Deep Rao'
#  'Mervin\xa0Harwood' 'Akshansh Chaudhary' 'Manish Saundriyal'
#  'keshar ansari' 'Zulema\xa0Perrine' 'Rayford\xa0Durgan' 'Atul Chaudhary'
#  'Roopal Chaudhary' 'Sergio\xa0Cusack' 'shiv kumar' 'Palmer\xa0Holmberg'
#  'Davis\xa0Gagner' 'Heeman Daga' 'pankaj kumar' 'Prakash Dhawale'
#  'Florencio\xa0Quiros' 'Herschel\xa0Flock' 'Preeti Mehra'
#  'Chloe\xa0Beiler' 'Vincenzo\xa0Mushrush' 'Doreen\xa0Amerman'
#  'Danny\xa0Bolton' 'Harsh Verma' 'Annett\xa0Mcmillen' 'Anmol Mehre'
#  'Prashant singh' 'Anchal Pandey' 'Vikrant Soneja' 'Emil\xa0Knudsen'
#  'Eesha Yadav' 'bhagwati prasad' 'Gunjan Singh' 'Aditya Kumar'
#  'rahul kumar' 'Randy\xa0Fontana' 'Abhiskek Kumar' 'Ahdarsha Jha'
#  'kamal jit singh' 'Jayant Kalra' 'Darin\xa0Vath' 'Roop Sachdeva'
#  'Aman Singh' 'Sherell\xa0Peace' 'Tarun Garg' 'Akasnah Arora'
#  'Saneel Tyagi' 'Rajat Bansal' 'Harpreet Bedi' 'bablu regar' 'shyam kumar'
#  'Abhishek Singhal' 'Sultan Khan' 'Darla\xa0Dickinson'
#  'Manisha Saundriyal' 'Akshay Gosh' 'Kaniksh Dhyani' 'Sanchita Pant'
#  'Rishab Jain' 'Leticia\xa0Denton' 'Manisha Gulati' 'Kendra Tripathi'
#  'Kanika Sharma' 'khadak singh' 'R. T. Ramakrishnan' 'Md Irshad'
#  'Ranjnesh Tanwar' 'Andrew\xa0Michalowski' 'Rodney\xa0Wilkison'
#  'Nanette\xa0Hennessee' 'Harshita Singh' 'Anish Jonson' 'Tanu Panwar'
#  'Shalendra D.' 'Laurine\xa0Quintanar' 'Kamal Deep' 'Karna Bhuvennant'
#  'Vishvajeet Kumar' 'Virak Kandpal' 'Kim\xa0Tavernier' 'rohit'
#  'Anju Nanda' 'Manish Johar' 'Sarwan Singh' 'Arron\xa0Hack' 'Akshant Garg'
#  'Vikram Rawat' 'Ahswini Saini' 'shiv shakti singh' 'Sierra\xa0Yamamoto'
#  'Taran Singh' 'Anand Vikram' 'Abhiskhek  D' 'Jackie\xa0Wolfson'
#  'Umesh Kholi' 'Atul Kumar' 'kailash kumar' 'lalit kathuriya'
#  'birender mandal' 'Son\xa0Mcconnaughy' 'Eula\xa0Hallowell' 'Raj Pinani'
#  'mohd ataullah' 'Akshit Khanna' 'Ravi Chaudhary' 'Siddhant Gaur'
#  'Devendra Vishvakarma' 'ram dutt gupta' 'Chad\xa0Jamal'
#  'Thurman\xa0Niemi' 'Prakash Srinivas' 'Millicent\xa0Firth' 'Varun Bhel'
#  'Lakendra\xa0Hartgrove' 'Deepak Chandra Prakash' 'Kamal Chandra'
#  'Donovan\xa0Rockwood' 'Leeladhar Pandey' 'pooran chand' 'Prashant Rawat'
#  'Sangeet Daga' 'Taran Deep' 'Sharavan Singh' 'Akhil Biyas' 'Rishab Bhatt'
#  'Mahesh Gulati' 'Jarred\xa0Parrino' 'Beutune Varma' 'Cameron\xa0Deleeuw'
#  'Aditya Tondon' 'vinit katariya' 'Jose\xa0Gamber' 'Rateesh Singh'
#  'Ranjan Prakash' 'Johnna\xa0Lemay' 'Jasmin kaur' 'Genny\xa0Mcgivney'
#  'sheak shakir' 'Naveen Dogra' 'Vaibhav singh' 'Martin\xa0Cheyne'
#  'Kittie\xa0Selvey' 'Vaibhav Somaskandan' 'Royal\xa0Garofalo'
#  'Kamaldeep Singh' 'Antonio\xa0Yelvington' 'jamil khan' 'Aman Gupta'
#  'Himanshu Upadhiya' 'Varun  Behl' 'Brenton\xa0Launius' 'Preetan Gujar'
#  'Geoffrey\xa0Recker' 'Russ\xa0Vaz' 'Aastha Gandhi' 'Sai S Sabitha'
#  'sharat chandran' 'Tom\xa0Blanca' 'maansingh aswal' 'farmaan khan'
#  'Sanjeev Diwakar' 'Navita Chauhan' 'Sumita Verma' 'gurmit singh'
#  'Mayank Praveen' 'Heath\xa0Mullarkey' 'Zachary\xa0Oconner'
#  'Upendra Bhatt' 'Himanshu Daga' 'Matt\xa0Redel' 'Amit Jain'
#  'Joe\xa0Castorena' 'ramdin verma' 'Cori\xa0Gillispie' 'Sanjeev Talreja'
#  'Sumit Arora' 'Preston\xa0Dumire' 'Arti Bindra' 'Ike\xa0Deppen'
#  'Waseem Khan' 'Ali Rafiq' 'Uzaar Ali' 'Cleotilde\xa0Biron']
# Deal Cost : [ 150000.    744705.88   60000.   ... 1404411.77  777058.82 3042058.82]
# Deal Status Code : ['Won' 'Lost']

# %% [markdown]
# ### Outlier Detection

# %%
df.describe()
# Out:
#           Deal Cost
# count  1.006100e+04
# mean   7.668969e+05
# std    1.619894e+06
# min    0.000000e+00
# 25%    1.897059e+05
# 50%    3.823529e+05
# 75%    7.647059e+05
# max    3.676471e+07

# %%
plt.figure(figsize=(12, 6)) 
sns.boxplot(df['Deal Cost'])
# Out:
# <AxesSubplot:xlabel='Deal Cost'>

# %% [markdown]
# ### Capping of Outlier

# %%
Q1=np.percentile(df['Deal Cost'],25)
Q3=np.percentile(df['Deal Cost'],75)

# %%
iqr=Q3-Q1
upper=Q3+1.5*iqr

# %%
df['Deal Cost']=np.where(df['Deal Cost']>upper,upper,df['Deal Cost'])

# %%
plt.figure(figsize=(12, 6)) 
sns.boxplot(df['Deal Cost'])
# Out:
# <AxesSubplot:xlabel='Deal Cost'>

# %% [markdown]
# ### Imbalance Check

# %%
df['Deal Status Code'].value_counts(normalize=True)*100 #2*Won>Lost therefore,Balanced Data
# Out:
# Lost    62.677666
# Won     37.322334
# Name: Deal Status Code, dtype: float64

# %% [markdown]
# ## EDA

# %%
Client_Category_index = df['Client Category'].value_counts().index

# %%
Client_Category_index
# Out:
# Index(['Others', 'Internal', 'Services_based', 'Tech', 'Domestic Public Bank',
#        'International Bank', 'Consulting', 'Finance', 'Telecom', 'Power ind',
#        'Domestic Private Bank', 'Insurance', 'Consumer Good', 'Automobiles',
#        'Infrastructure', 'Domestic Bank', 'Retail_market', 'Govt',
#        'Hospitality', 'Manufacturing', 'Pharma', 'Healthcare', 'Electronics',
#        'Media_Journal', 'Industries', 'Research Development', 'Energy',
#        'Knowledge', 'Management', 'Govt Bank Special', 'Payment', 'Energy ',
#        'e-commerce', 'Airpline', 'Holding', 'International Org', 'Logistics',
#        'Real Estate', 'Share_market', 'Tax_audit', 'Medical '],
#       dtype='object')

# %%
plt.pie(Client_Category[:5], labels=Client_Category_index[:5],autopct='%1.2f%%')
plt.show()

# %%
Client_Category[:5].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
Solution_Type = df['Solution Type'].value_counts()

# %%
Solution_Type
# Out:
# Solution 32    1439
# Solution 9     1418
# Solution 10    1016
# Solution 39     585
# Solution 67     584
#                ...
# Solution 60       1
# Solution 57       1
# Solution 56       1
# Solution 18       1
# Solution 19       1
# Name: Solution Type, Length: 67, dtype: int64

# %%
Solution_Type_index = df['Solution Type'].value_counts().index
Solution_Type_index
# Out:
# Index(['Solution 32', 'Solution 9', 'Solution 10', 'Solution 39',
#        'Solution 67', 'Solution 37', 'Solution 59', 'Solution 12',
#        'Solution 8', 'Solution 29', 'Solution 6', 'Solution 13', 'Solution 31',
#        'Solution 4', 'Solution 28', 'Solution 38', 'Solution 7', 'Solution 11',
#        'Solution 20', 'Solution 52', 'Solution 40', 'Solution 30',
#        'Solution 14', 'Solution 36', 'Solution 58', 'Solution 47',
#        'Solution 35', 'Solution 55', 'Solution 33', 'Solution 48',
#        'Solution 16', 'Solution 26', 'Solution 49', 'Solution 2',
#        'Solution 34', 'Solution 42', 'Solution 61', 'Solution 41',
#        'Solution 65', 'Solution 44', 'Solution 17', 'Solution 15',
#        'Solution 50', 'Solution 25', 'Solution 1', 'Solution 43',
#        'Solution 24', 'Solution 62', 'Solution 5', 'Solution 27',
#        'Solution 46', 'Solution 3', 'Solution 22', 'Solution 53',
#        'Solution 51', 'Solution 45', 'Solution 63', 'Solution 23',
#        'Solution 54', 'Solution 21', 'Solution 66', 'Solution 64',
#        'Solution 60', 'Solution 57', 'Solution 56', 'Solution 18',
#        'Solution 19'],
#       dtype='object')

# %%
plt.pie(Solution_Type[:5], labels=Solution_Type_index[:5],autopct='%1.2f%%')
plt.show()

# %%
Solution_Type[:5].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
Sector = df['Sector'].value_counts()
Sector
# Out:
# Sector 23    2693
# Sector 2     1748
# Sector 20     773
# Sector 12     607
# Sector 24     578
# Sector 17     474
# Sector 16     474
# Sector 15     387
# Sector 9      369
# Sector 25     273
# Sector 18     251
# Sector 1      231
# Sector 13     185
# Sector 22     144
# Sector 19     142
# Sector 3      135
# Sector 4      128
# Sector 11     114
# Sector 14     109
# Sector 6       96
# Sector 5       64
# Sector 8       39
# Sector 21      30
# Sector 7       14
# Sector 10       3
# Name: Sector, dtype: int64

# %%
Sector_index = df['Sector'].value_counts().index
Sector_index
# Out:
# Index(['Sector 23', 'Sector 2', 'Sector 20', 'Sector 12', 'Sector 24',
#        'Sector 17', 'Sector 16', 'Sector 15', 'Sector 9', 'Sector 25',
#        'Sector 18', 'Sector 1', 'Sector 13', 'Sector 22', 'Sector 19',
#        'Sector 3', 'Sector 4', 'Sector 11', 'Sector 14', 'Sector 6',
#        'Sector 5', 'Sector 8', 'Sector 21', 'Sector 7', 'Sector 10'],
#       dtype='object')

# %%
plt.pie(Sector[:5], labels=Sector_index[:5],autopct='%1.2f%%')
plt.show()

# %%
Sector[:5].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
Location = df['Location'].value_counts()
Location
# Out:
# L10       3360
# L5        2328
# L1        1572
# Others     817
# L3         556
# L11        367
# L12        276
# L9         240
# L7         238
# L4         188
# L6         100
# L8          11
# L2           8
# Name: Location, dtype: int64

# %%
Location_index = df['Location'].value_counts().index
Location_index
# Out:
# Index(['L10', 'L5', 'L1', 'Others', 'L3', 'L11', 'L12', 'L9', 'L7', 'L4', 'L6',
#        'L8', 'L2'],
#       dtype='object')

# %%
plt.pie(Location[:5], labels=Location_index[:5],autopct='%1.2f%%')
plt.show()

# %%
Location[:5].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
VP_Name = df['VP Name'].value_counts()
VP_Name
# Out:
# Mervin Harwood         1166
# Ankita Aggarwal        1143
# Sargar Deep Rao         956
# Long Bergstrom          921
# Mangesh K. Singh        812
# Rosanna Maynez          662
# Ekta Zutshi             550
# Rahul Bajpai            523
# neeraj kumar            471
# Son Mcconnaughy         232
# som dutt                220
# Hardeep Suksma          208
# Brendon Wycoff          189
# Clinton Mani            184
# Saurabh Singh           176
# Jewell Tunstall         156
# Rudraksh Sharma         147
# Gopa Trilochana         136
# Russell Dahlen          133
# Molly Eakes             126
# Alam Syed               126
# Gaurav Sameria          114
# Varsha Arora            104
# Gayle Molter            104
# Vidur Hukle             100
# Earline Langton          82
# Manpreet Singh           46
# Mayank Mewar             41
# Marcella Mo              32
# Rahul Kocher             32
# Man Suddeth              29
# Jitendra Choudhary       28
# Prashant Rawat           27
# Lilli Storrs             26
# Vikram Rawat             17
# Kamelesh Srinivasan      15
# Dennis Faux              13
# Visvajeet Das             3
# Waylon Mulder             3
# P. Somya                  2
# Kirk Hofmeister           2
# Sarthak Batra             2
# md. afsar                 2
# Name: VP Name, dtype: int64

# %%
VP_Name_index = df['VP Name'].value_counts().index
VP_Name_index
# Out:
# Index(['Mervin Harwood', 'Ankita Aggarwal', 'Sargar Deep Rao',
#        'Long Bergstrom', 'Mangesh K. Singh', 'Rosanna Maynez', 'Ekta Zutshi',
#        'Rahul Bajpai', 'neeraj kumar', 'Son Mcconnaughy', 'som dutt',
#        'Hardeep Suksma', 'Brendon Wycoff', 'Clinton Mani', 'Saurabh Singh',
#        'Jewell Tunstall', 'Rudraksh Sharma', 'Gopa Trilochana',
#        'Russell Dahlen', 'Molly Eakes', 'Alam Syed', 'Gaurav Sameria',
#        'Varsha Arora', 'Gayle Molter', 'Vidur Hukle', 'Earline Langton',
#        'Manpreet Singh', 'Mayank Mewar', 'Marcella Mo', 'Rahul Kocher',
#        'Man Suddeth', 'Jitendra Choudhary', 'Prashant Rawat', 'Lilli Storrs',
#        'Vikram Rawat', 'Kamelesh Srinivasan', 'Dennis Faux', 'Visvajeet Das',
#        'Waylon Mulder', 'P. Somya', 'Kirk Hofmeister', 'Sarthak Batra',
#        'md. afsar'],
#       dtype='object')

# %%
plt.pie(VP_Name[:5], labels=VP_Name_index[:5],autopct='%1.2f%%')
plt.show()

# %%
VP_Name[:5].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
Manager_Name = df['Manager Name'].value_counts()
Manager_Name
# Out:
# Molly Eakes        323
# Rudraksh Sharma    270
# Desmond Krout      230
# Gayle Molter       186
# Manpreet Singh     181
#                   ...
# Anju Nanda           1
# Taran Singh          1
# pooran chand         1
# Rishab Bhatt         1
# Cleotilde Biron      1
# Name: Manager Name, Length: 278, dtype: int64

# %%
Manager_Name_index = df['Manager Name'].value_counts().index
Manager_Name_index
# Out:
# Index(['Molly Eakes', 'Rudraksh Sharma', 'Desmond Krout', 'Gayle Molter',
#        'Manpreet Singh', 'Rosana Yokum', 'Rayford Durgan', 'Manish Saundriyal',
#        'Jewell Tunstall', 'Hardeep Suksma',
#        ...
#        'Palmer Holmberg', 'Heath Mullarkey', 'Sultan Khan', 'Aastha Gandhi',
#        'Anish Jonson', 'Anju Nanda', 'Taran Singh', 'pooran chand',
#        'Rishab Bhatt', 'Cleotilde Biron'],
#       dtype='object', length=278)

# %%
plt.pie(Manager_Name[:5], labels=Manager_Name_index[:5],autopct='%1.2f%%')
plt.show()

# %%
Manager_Name[:5].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
Deal_Status_Code = df['Deal Status Code'].value_counts()
Deal_Status_Code
# Out:
# Lost    6306
# Won     3755
# Name: Deal Status Code, dtype: int64

# %%
Deal_Status_Code_index = df['Deal Status Code'].value_counts().index
Deal_Status_Code_index
# Out:
# Index(['Lost', 'Won'], dtype='object')

# %%
plt.pie(Deal_Status_Code[:], labels=Deal_Status_Code_index[:5],autopct='%1.2f%%')
plt.show()

# %%
Deal_Status_Code[:].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Checking the relation between 'Deal Status Code' with different variables

# %%
rel_client_cat=df.groupby(['Deal Status Code', 'Client Category']).size().reset_index().pivot(columns = 'Deal Status Code', index = 'Client Category', values = 0)
rel_client_cat.sort_values(by=['Won'],ascending=False)[:15].plot(kind='bar',figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Client Category'>

# %%
rel_solution_type=df.groupby(['Deal Status Code', 'Solution Type']).size().reset_index().pivot(columns = 'Deal Status Code', index = 'Solution Type', values = 0)
rel_solution_type.sort_values(by=['Won'],ascending=False)[:15].plot(kind='bar',figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Solution Type'>

# %%
rel_sector=df.groupby(['Deal Status Code', 'Sector']).size().reset_index().pivot(columns = 'Deal Status Code', index = 'Sector', values = 0)
rel_sector.sort_values(by=['Won'],ascending=False)[:15].plot(kind='bar',figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Sector'>

# %%
rel_location=df.groupby(['Deal Status Code', 'Location']).size().reset_index().pivot(columns = 'Deal Status Code', index = 'Location', values = 0)
rel_location.sort_values(by=['Won'],ascending=False)[:15].plot(kind='bar',figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
rel_VP_Name=df.groupby(['Deal Status Code', 'VP Name']).size().reset_index().pivot(columns = 'Deal Status Code', index = 'VP Name', values = 0)
rel_VP_Name.sort_values(by=['Won'],ascending=False)[:15].plot(kind='bar',figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='VP Name'>

# %%
rel_Manager_Name=df.groupby(['Deal Status Code', 'Manager Name']).size().reset_index().pivot(columns = 'Deal Status Code', index = 'Manager Name', values = 0)
rel_Manager_Name.sort_values(by=['Won'],ascending=False)[:15].plot(kind='bar',figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Manager Name'>

# %% [markdown]
# ### Checking the relation between 'Deal Cost' with different variables

# %%
pd.pivot_table(df, index = 'Client Category', columns='Deal Status Code',values='Deal Cost').sort_values(by=['Won'],ascending=False).plot(kind='bar',figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Client Category'>

# %%
pd.pivot_table(df, index = 'Solution Type', columns='Deal Status Code',values='Deal Cost').sort_values(by=['Won'],ascending=False).plot(kind='bar',figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Solution Type'>

# %%
pd.pivot_table(df, index = 'Sector', columns='Deal Status Code',values='Deal Cost').sort_values(by=['Won'],ascending=False).plot(kind='bar',figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Sector'>

# %%
pd.pivot_table(df, index = 'Location', columns='Deal Status Code',values='Deal Cost').sort_values(by=['Won'],ascending=False).plot(kind='bar',figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
pd.pivot_table(df, index = 'VP Name', columns='Deal Status Code',values='Deal Cost').sort_values(by=['Won'],ascending=False).plot(kind='bar',figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='VP Name'>

# %%
pd.pivot_table(df, index = 'Manager Name', columns='Deal Status Code',values='Deal Cost').sort_values(by=['Won'],ascending=False)[:46].plot(kind='bar',figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Manager Name'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10061 entries, 0 to 10060
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Client Category   10061 non-null  object
#  1   Solution Type     10061 non-null  object
#  2   Deal Date         10061 non-null  datetime64[ns]
#  3   Sector            10061 non-null  object
#  4   Location          10061 non-null  object
#  5   VP Name           10061 non-null  object
#  6   Manager Name      10061 non-null  object
#  7   Deal Cost         10061 non-null  float64
#  8   Deal Status Code  10061 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 707.5+ KB

# %%
df['Deal_Date_year'] = df['Deal Date'].dt.year

# %%
df.head()
# Out:
#   Client Category Solution Type  Deal Date     Sector Location      VP Name  \
# 0         Telecom    Solution 7 2012-03-27  Sector 24       L5  Ekta Zutshi
# 1         Telecom    Solution 7 2012-09-25  Sector 24       L5  Ekta Zutshi
# 2        Internal   Solution 59 2011-08-01  Sector 20   Others  Ekta Zutshi
# 3        Internal   Solution 59 2011-04-28  Sector 20   Others  Ekta Zutshi
# 4        Internal   Solution 32 2011-06-03  Sector 20   Others  Ekta Zutshi
#
#       Manager Name  Deal Cost Deal Status Code  Deal_Date_year
# 0  Gopa Trilochana  150000.00              Won            2012
# 1  Gopa Trilochana  744705.88              Won            2012
# 2   Russell Dahlen   60000.00             Lost            2011
# 3   Russell Dahlen   60000.00             Lost            2011
# 4   Russell Dahlen   80882.35             Lost            2011

# %%
sns.displot(df.Deal_Date_year)

# %%
df['Deal_date_month'] = df['Deal Date'].dt.month

# %%
df.head()
# Out:
#   Client Category Solution Type  Deal Date     Sector Location      VP Name  \
# 0         Telecom    Solution 7 2012-03-27  Sector 24       L5  Ekta Zutshi
# 1         Telecom    Solution 7 2012-09-25  Sector 24       L5  Ekta Zutshi
# 2        Internal   Solution 59 2011-08-01  Sector 20   Others  Ekta Zutshi
# 3        Internal   Solution 59 2011-04-28  Sector 20   Others  Ekta Zutshi
# 4        Internal   Solution 32 2011-06-03  Sector 20   Others  Ekta Zutshi
#
#       Manager Name  Deal Cost Deal Status Code  Deal_Date_year  \
# 0  Gopa Trilochana  150000.00              Won            2012
# 1  Gopa Trilochana  744705.88              Won            2012
# 2   Russell Dahlen   60000.00             Lost            2011
# 3   Russell Dahlen   60000.00             Lost            2011
# 4   Russell Dahlen   80882.35             Lost            2011
#
#    Deal_date_month
# 0                3
# 1                9
# 2                8
# 3                4
# 4                6

# %%
sns.histplot(df.Deal_date_month, bins = 12)
# Out:
# <AxesSubplot:xlabel='Deal_date_month', ylabel='Count'>

# %%
df['Deal_date_quarter'] = df['Deal Date'].dt.quarter

# %%
df.head()
# Out:
#   Client Category Solution Type  Deal Date     Sector Location      VP Name  \
# 0         Telecom    Solution 7 2012-03-27  Sector 24       L5  Ekta Zutshi
# 1         Telecom    Solution 7 2012-09-25  Sector 24       L5  Ekta Zutshi
# 2        Internal   Solution 59 2011-08-01  Sector 20   Others  Ekta Zutshi
# 3        Internal   Solution 59 2011-04-28  Sector 20   Others  Ekta Zutshi
# 4        Internal   Solution 32 2011-06-03  Sector 20   Others  Ekta Zutshi
#
#       Manager Name  Deal Cost Deal Status Code  Deal_Date_year  \
# 0  Gopa Trilochana  150000.00              Won            2012
# 1  Gopa Trilochana  744705.88              Won            2012
# 2   Russell Dahlen   60000.00             Lost            2011
# 3   Russell Dahlen   60000.00             Lost            2011
# 4   Russell Dahlen   80882.35             Lost            2011
#
#    Deal_date_month  Deal_date_quarter
# 0                3                  1
# 1                9                  3
# 2                8                  3
# 3                4                  2
# 4                6                  2

# %%
sns.histplot(df.Deal_date_quarter, bins = 4)
# Out:
# <AxesSubplot:xlabel='Deal_date_quarter', ylabel='Count'>

# %%
df = df.drop(['Deal Date'], axis=1)

# %%
df.head()
# Out:
#   Client Category Solution Type     Sector Location      VP Name  \
# 0         Telecom    Solution 7  Sector 24       L5  Ekta Zutshi
# 1         Telecom    Solution 7  Sector 24       L5  Ekta Zutshi
# 2        Internal   Solution 59  Sector 20   Others  Ekta Zutshi
# 3        Internal   Solution 59  Sector 20   Others  Ekta Zutshi
# 4        Internal   Solution 32  Sector 20   Others  Ekta Zutshi
#
#       Manager Name  Deal Cost Deal Status Code  Deal_Date_year  \
# 0  Gopa Trilochana  150000.00              Won            2012
# 1  Gopa Trilochana  744705.88              Won            2012
# 2   Russell Dahlen   60000.00             Lost            2011
# 3   Russell Dahlen   60000.00             Lost            2011
# 4   Russell Dahlen   80882.35             Lost            2011
#
#    Deal_date_month  Deal_date_quarter
# 0                3                  1
# 1                9                  3
# 2                8                  3
# 3                4                  2
# 4                6                  2

# %%
df.columns
# Out:
# Index(['Client Category', 'Solution Type', 'Sector', 'Location', 'VP Name',
#        'Manager Name', 'Deal Cost', 'Deal Status Code', 'Deal_Date_year',
#        'Deal_date_month', 'Deal_date_quarter'],
#       dtype='object')

# %%
col=['Client Category', 'Solution Type', 'Sector', 'Location', 'VP Name',
       'Manager Name','Deal Status Code']

for i in col:
    df[i]=df[i].astype('category')
    df[i]=df[i].cat.codes

# %%
df.head()
# Out:
#    Client Category  Solution Type  Sector  Location  VP Name  Manager Name  \
# 0               39             64      16         7        6            82
# 1               39             64      16         7        6            82
# 2               19             54      12        12        6           183
# 3               19             54      12        12        6           183
# 4               19             25      12        12        6           183
#
#    Deal Cost  Deal Status Code  Deal_Date_year  Deal_date_month  \
# 0  150000.00                 1            2012                3
# 1  744705.88                 1            2012                9
# 2   60000.00                 0            2011                8
# 3   60000.00                 0            2011                4
# 4   80882.35                 0            2011                6
#
#    Deal_date_quarter
# 0                  1
# 1                  3
# 2                  3
# 3                  2
# 4                  2

# %%
dataset.nunique()
# Out:
# Client Category       41
# Solution Type         67
# Deal Date           2555
# Sector                25
# Location              13
# VP Name               43
# Manager Name         278
# Deal Cost           1469
# Deal Status Code       2
# dtype: int64

# %%
df.nunique()
# Out:
# Client Category        41
# Solution Type          67
# Sector                 25
# Location               13
# VP Name                43
# Manager Name          278
# Deal Cost            1171
# Deal Status Code        2
# Deal_Date_year          9
# Deal_date_month        12
# Deal_date_quarter       4
# dtype: int64

# %% [markdown]
# ## Spliting Dependent & Independent Variable

# %%
x = df.drop(['Deal Status Code'], axis=1)
y = df['Deal Status Code']

# %%
x = x.iloc[:,0:7]

# %%
x.head()
# Out:
#    Client Category  Solution Type  Sector  Location  VP Name  Manager Name  \
# 0               39             64      16         7        6            82
# 1               39             64      16         7        6            82
# 2               19             54      12        12        6           183
# 3               19             54      12        12        6           183
# 4               19             25      12        12        6           183
#
#    Deal Cost
# 0  150000.00
# 1  744705.88
# 2   60000.00
# 3   60000.00
# 4   80882.35

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: Deal Status Code, dtype: int8

# %% [markdown]
# ## Standardizing Independent Data using StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x1 = sc.fit_transform(x)

# %%
x1
# Out:
# array([[ 1.40299487,  1.29765094,  0.78535088, ..., -1.11119992,
#         -0.71544412, -0.83064732],
#        [ 1.40299487,  1.29765094,  0.78535088, ..., -1.11119992,
#         -0.71544412,  0.39335564],
#        [-0.33339304,  0.86106354,  0.01663725, ..., -1.11119992,
#          0.60004268, -1.01588219],
#        ...,
#        [ 0.70843971,  1.38496843,  2.32277814, ...,  0.79154462,
#          0.58701806,  0.07131332],
#        [ 0.70843971,  1.0356985 ,  2.32277814, ..., -0.03573561,
#         -1.13223202,  2.20968646],
#        [ 0.44798152,  1.38496843, -1.71296842, ...,  1.20518474,
#          1.0298552 , -0.83670075]])

# %% [markdown]
# ## Training & Testing Split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x1, y, train_size=0.75,random_state=101)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logit = LogisticRegression()
logit.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_test = logit.predict(x_test)
y_pred_train = logit.predict(x_train)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score,precision_score,recall_score,roc_auc_score,roc_curve

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_train, y_pred_train)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for training data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_test, y_pred_test)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for testing data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print("Accuracy of training dataset:",accuracy_score(y_train, y_pred_train)*100,'%')
print("Precision of training dataset:",precision_score(y_train, y_pred_train)*100,'%')
print("Recall of training dataset:",recall_score(y_train, y_pred_train)*100,'%')
# Out:
# Accuracy of training dataset: 61.868787276341955 %
# Precision of training dataset: 37.93103448275862 %
# Recall of training dataset: 0.3832752613240418 %

# %%
print("Accuracy of testing dataset:",accuracy_score(y_test, y_pred_test)*100,'%')
print("Precision of testing dataset:",precision_score(y_test, y_pred_test)*100,'%')
print("Recall of testing dataset:",recall_score(y_test, y_pred_test)*100,'%')
# Out:
# Accuracy of testing dataset: 64.78537360890301 %
# Precision of testing dataset: 46.666666666666664 %
# Recall of testing dataset: 0.7909604519774011 %

# %%
print(classification_report(y_train, y_pred_train))
print("###"*20)
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.76      4675
#            1       0.38      0.00      0.01      2870
#
#     accuracy                           0.62      7545
#    macro avg       0.50      0.50      0.39      7545
# weighted avg       0.53      0.62      0.48      7545
#
# ############################################################
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79      1631
#            1       0.47      0.01      0.02       885
#
#     accuracy                           0.65      2516
#    macro avg       0.56      0.50      0.40      2516
# weighted avg       0.58      0.65      0.51      2516

# %% [markdown]
# ## Cross Validation (k-fold method)

# %%
from sklearn.model_selection import cross_val_score
accuracy_train = cross_val_score(logit, x_train, y_train, cv=15)
accuracy_test = cross_val_score(logit, x_test, y_test, cv=15)
print(accuracy_train)
print("###"*20)
print(accuracy_test)
# Out:
# [0.62027833 0.62027833 0.61829026 0.62027833 0.61630219 0.61829026
#  0.62027833 0.62027833 0.61630219 0.61829026 0.6222664  0.61630219
#  0.61630219 0.6222664  0.61232604]
# ############################################################
# [0.64880952 0.64880952 0.64880952 0.64880952 0.64880952 0.64880952
#  0.64880952 0.64880952 0.64880952 0.64880952 0.64880952 0.64670659
#  0.64670659 0.64670659 0.64670659]

# %% [markdown]
# ### As we are getting high bais we will try with other models

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model=DecisionTreeClassifier()

# %%
from sklearn.model_selection import GridSearchCV

# %%
import time

# %%
# start = time.time()
# param_dist = {'max_depth': [4,5,6,7,8,9,10,11,12,15,20,30,40,50,70,90,120,150],
#               'max_features': ['auto', 'sqrt', 'log2', None],
#               'criterion': ['gini','entropy']}
# cv_dt = GridSearchCV(dt_model, cv = 10,
#                      param_grid=param_dist, 
#                      n_jobs = 1)
# cv_dt.fit(x_train, y_train)
# print('Best Parameters using grid search: \n', cv_dt.best_params_)
# end = time.time()
# print('Time taken in grid search: {0: .2f}'.format(end - start))

# %%
# Best Parameters using grid search: 
#  {'criterion': 'entropy', 'max_depth': 120, 'max_features': 'sqrt'}
# Time taken in grid search:  34.96

# %%
dt_model.set_params(criterion='entropy', max_depth=120, max_features='sqrt')
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=120, max_features='sqrt')

# %%
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=120, max_features='sqrt')

# %%
dt_importance=dt_model.feature_importances_

# %%
pd.Series(dt_importance,index=x.columns).sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
y_pred_test_dt = dt_model.predict(x_test)
y_pred_train_dt = dt_model.predict(x_train)

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_train, y_pred_train_dt)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for training data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_test, y_pred_test_dt)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for testing data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print("Accuracy of training dataset:",accuracy_score(y_train, y_pred_train_dt)*100,'%')
print("Precision of training dataset:",precision_score(y_train, y_pred_train_dt)*100,'%')
print("Recall of training dataset:",recall_score(y_train, y_pred_train_dt)*100,'%')
# Out:
# Accuracy of training dataset: 99.56262425447316 %
# Precision of training dataset: 99.92960225272792 %
# Recall of training dataset: 98.9198606271777 %

# %%
print("Accuracy of testing dataset:",accuracy_score(y_test, y_pred_test_dt)*100,'%')
print("Precision of testing dataset:",precision_score(y_test, y_pred_test_dt)*100,'%')
print("Recall of testing dataset:",recall_score(y_test, y_pred_test_dt)*100,'%')
# Out:
# Accuracy of testing dataset: 81.51828298887122 %
# Precision of testing dataset: 79.00552486187846 %
# Recall of testing dataset: 64.63276836158191 %

# %%
y_pred_test_prob=dt_model.predict_proba(x_test)[::,1]

# %%
fpr, tpr, _ = roc_curve(y_test,  y_pred_test_prob)
auc = roc_auc_score(y_test, y_pred_test_prob)

# %%
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
print(classification_report(y_train, y_pred_train_dt))
print("###"*20)
print(classification_report(y_test, y_pred_test_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      4675
#            1       1.00      0.99      0.99      2870
#
#     accuracy                           1.00      7545
#    macro avg       1.00      0.99      1.00      7545
# weighted avg       1.00      1.00      1.00      7545
#
# ############################################################
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.86      1631
#            1       0.79      0.65      0.71       885
#
#     accuracy                           0.82      2516
#    macro avg       0.81      0.78      0.79      2516
# weighted avg       0.81      0.82      0.81      2516

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model=RandomForestClassifier()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# ### Radomized Search CV

# %%
# n_estimators = [int(x) for x in range(100,600)] 
# max_features = ['auto', 'sqrt'] 
# max_depth = [int(x) for x in range(1,6)] 
# min_samples_split = [4,5,6,8,10,12] 
# min_samples_leaf = [3,4,5,6] 
# bootstrap = [True, False] 

# random_grid = {'n_estimators': n_estimators,

# 'max_features': max_features,

# 'max_depth': max_depth,

# 'min_samples_split': min_samples_split,

# 'min_samples_leaf': min_samples_leaf,

# 'bootstrap': bootstrap}

# %%
# start = time.time()

# rs_rf=RandomizedSearchCV(rf_model,param_distributions = random_grid,cv = 10, n_jobs = 1,n_iter=100)

# rs_rf.fit(x_train, y_train)
# print('Best Parameters using randomized search: \n', rs_rf.best_params_)
# end = time.time()
# print('Time taken in randomized search: {0: .2f}'.format(end - start))

# %%
# Best Parameters using randomized search: 
#  {'n_estimators': 152, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': 5, 'bootstrap': True}
# Time taken in randomized search:  2021.92

# %% [markdown]
# ### Grid Search CV

# %%
# n_estimators_cv=[110,120,130,140,150]
# max_features_cv = ['auto', 'sqrt'] 
# max_depth_cv = [int(x) for x in range(1,6)] 
# min_samples_split_cv = [3,4,5,6,8] 
# min_samples_leaf_cv = [3,4,5,6] 
# bootstrap_cv= [True, False] 

# grid_cv = {'n_estimators': n_estimators_cv,

# 'max_features': max_features_cv,

# 'max_depth': max_depth_cv,

# 'min_samples_split': min_samples_split_cv,

# 'min_samples_leaf': min_samples_leaf_cv,

# 'bootstrap': bootstrap_cv}

# %%
# start = time.time()

# cv_rf=GridSearchCV(rf_model,param_grid=grid_cv,cv = 10, n_jobs = -1)

# cv_rf.fit(x_train, y_train)
# print('Best Parameters using grid search: \n', cv_rf.best_params_)
# end = time.time()

# %%
# Best Parameters using grid search: 
#  {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 4, 'n_estimators': 110}

# %%
rf_model.set_params(n_estimators=110,min_samples_split=4,min_samples_leaf=6,max_features='auto',max_depth=5
                ,bootstrap=False)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=5, max_features='auto',
#                        min_samples_leaf=6, min_samples_split=4,
#                        n_estimators=110)

# %%
rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=5, max_features='auto',
#                        min_samples_leaf=6, min_samples_split=4,
#                        n_estimators=110)

# %%
rf_importance=rf_model.feature_importances_

# %%
pd.Series(rf_importance,index=x.columns).sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
y_pred_test_rf = rf_model.predict(x_test)
y_pred_train_rf = rf_model.predict(x_train)

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_train, y_pred_train_rf)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for training data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_test, y_pred_test_rf)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for testing data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print("Accuracy of training dataset:",accuracy_score(y_train, y_pred_train_rf)*100,'%')
print("Precision of training dataset:",precision_score(y_train, y_pred_train_rf)*100,'%')
print("Recall of training dataset:",recall_score(y_train, y_pred_train_rf)*100,'%')
# Out:
# Accuracy of training dataset: 67.72697150430749 %
# Precision of training dataset: 84.688995215311 %
# Recall of training dataset: 18.501742160278745 %

# %%
print("Accuracy of testing dataset:",accuracy_score(y_test, y_pred_test_rf)*100,'%')
print("Precision of testing dataset:",precision_score(y_test, y_pred_test_rf)*100,'%')
print("Recall of testing dataset:",recall_score(y_test, y_pred_test_rf)*100,'%')
# Out:
# Accuracy of testing dataset: 69.2368839427663 %
# Precision of testing dataset: 77.33990147783251 %
# Recall of testing dataset: 17.740112994350284 %

# %%
y_pred_test_prob_rf=rf_model.predict_proba(x_test)[::,1]

# %%
fpr_rf, tpr_rf,_ = roc_curve(y_test,  y_pred_test_prob_rf)
auc_rf = roc_auc_score(y_test, y_pred_test_prob_rf)

# %%
plt.plot(fpr_rf,tpr_rf,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
print(classification_report(y_train, y_pred_train_rf))
print("###"*20)
print(classification_report(y_test, y_pred_test_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.98      0.79      4675
#            1       0.85      0.19      0.30      2870
#
#     accuracy                           0.68      7545
#    macro avg       0.75      0.58      0.55      7545
# weighted avg       0.73      0.68      0.60      7545
#
# ############################################################
#               precision    recall  f1-score   support
#
#            0       0.69      0.97      0.80      1631
#            1       0.77      0.18      0.29       885
#
#     accuracy                           0.69      2516
#    macro avg       0.73      0.57      0.55      2516
# weighted avg       0.72      0.69      0.62      2516

# %% [markdown]
# ### K-Nearest Neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier(n_neighbors=1)

# %%
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
y_train_pred_knn=knn_model.predict(x_train)
y_test_pred_knn = knn_model.predict(x_test)

# %%
print(classification_report(y_train, y_train_pred_knn))  
print('*'*20)
print(classification_report(y_test, y_test_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      4675
#            1       1.00      0.99      0.99      2870
#
#     accuracy                           1.00      7545
#    macro avg       1.00      0.99      0.99      7545
# weighted avg       1.00      1.00      1.00      7545
#
# ********************
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85      1631
#            1       0.76      0.62      0.68       885
#
#     accuracy                           0.80      2516
#    macro avg       0.79      0.76      0.77      2516
# weighted avg       0.79      0.80      0.79      2516

# %% [markdown]
# ### Detecting Optimal K value

# %%
error = []

# Calculating error for K values between 1 and 40
for i in range(1, 40):  
    knn_model = KNeighborsClassifier(n_neighbors=i)
    knn_model.fit(x_train, y_train)
    y_test_pred_knn = knn_model.predict(x_test)
    error.append(np.mean(y_test_pred_knn != y_test))

# %%
plt.figure(figsize=(12, 6))  
plt.plot(range(1, 40), error, color='red', linestyle='dashed', marker='o',  
         markerfacecolor='blue', markersize=10)
plt.title('Error Rate vs K Value')  
plt.xlabel('K Value')  
plt.ylabel('Mean Error')  
plt.show()

# %%
knn_model = KNeighborsClassifier(n_neighbors=6)

# %%
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
y_train_pred_knn=knn_model.predict(x_train)
y_test_pred_knn = knn_model.predict(x_test)

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_train, y_train_pred_knn)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for training data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_test, y_test_pred_knn)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for testing data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print("Accuracy of training dataset:",accuracy_score(y_train, y_train_pred_knn)*100,'%')
print("Precision of training dataset:",precision_score(y_train, y_train_pred_knn)*100,'%')
print("Recall of training dataset:",recall_score(y_train, y_train_pred_knn)*100,'%')
# Out:
# Accuracy of training dataset: 75.13585155732272 %
# Precision of training dataset: 77.42825607064017 %
# Recall of training dataset: 48.88501742160279 %

# %%
print("Accuracy of testing dataset:",accuracy_score(y_test, y_test_pred_knn)*100,'%')
print("Precision of testing dataset:",precision_score(y_test, y_test_pred_knn)*100,'%')
print("Recall of testing dataset:",recall_score(y_test, y_test_pred_knn)*100,'%')
# Out:
# Accuracy of testing dataset: 69.35612082670907 %
# Precision of testing dataset: 59.62837837837838 %
# Recall of testing dataset: 39.887005649717516 %

# %% [markdown]
# ### Cross Validation

# %%
knn_cv_accuracy = cross_val_score(knn_model, x1, y, cv=20)

print(knn_cv_accuracy)
print("###"*20)
print(knn_cv_accuracy.mean())
# Out:
# [0.60515873 0.59840954 0.6640159  0.60039761 0.63419483 0.65606362
#  0.61829026 0.62027833 0.65407555 0.67992048 0.56461233 0.56063618
#  0.67196819 0.55069583 0.61630219 0.64015905 0.62624254 0.63021869
#  0.6361829  0.58449304]
# ############################################################
# 0.6206157893906403

# %%
y_pred_test_prob_knn=knn_model.predict_proba(x_test)[::,1]

# %%
fpr_knn, tpr_knn, _ = roc_curve(y_test,  y_pred_test_prob_knn)
auc_knn = roc_auc_score(y_test, y_pred_test_prob_knn)

# %%
plt.plot(fpr_knn,tpr_knn,label="AUC="+str(auc_knn))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
print(classification_report(y_train, y_train_pred_knn))
print("###"*20)
print(classification_report(y_test, y_test_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.91      0.82      4675
#            1       0.77      0.49      0.60      2870
#
#     accuracy                           0.75      7545
#    macro avg       0.76      0.70      0.71      7545
# weighted avg       0.76      0.75      0.74      7545
#
# ############################################################
#               precision    recall  f1-score   support
#
#            0       0.72      0.85      0.78      1631
#            1       0.60      0.40      0.48       885
#
#     accuracy                           0.69      2516
#    macro avg       0.66      0.63      0.63      2516
# weighted avg       0.68      0.69      0.68      2516

# %% [markdown]
# ### Navie Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb_model = GaussianNB()

# %%
nb_model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred_test_nb = nb_model.predict(x_test)
y_pred_train_nb = nb_model.predict(x_train)

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_train, y_pred_train_nb)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for training data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_test, y_pred_test_nb)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for testing data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print("Accuracy of training dataset:",accuracy_score(y_train, y_pred_train_nb)*100,'%')
print("Precision of training dataset:",precision_score(y_train, y_pred_train_nb)*100,'%')
print("Recall of training dataset:",recall_score(y_train, y_pred_train_nb)*100,'%')
# Out:
# Accuracy of training dataset: 62.21338634857522 %
# Precision of training dataset: 71.11111111111111 %
# Recall of training dataset: 1.1149825783972125 %

# %%
print("Accuracy of testing dataset:",accuracy_score(y_test, y_pred_test_nb)*100,'%')
print("Precision of testing dataset:",precision_score(y_test, y_pred_test_nb)*100,'%')
print("Recall of testing dataset:",recall_score(y_test, y_pred_test_nb)*100,'%')
# Out:
# Accuracy of testing dataset: 64.98410174880763 %
# Precision of testing dataset: 64.28571428571429 %
# Recall of testing dataset: 1.0169491525423728 %

# %%
print(classification_report(y_train, y_pred_train_nb))
print("###"*20)
print(classification_report(y_test, y_pred_test_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77      4675
#            1       0.71      0.01      0.02      2870
#
#     accuracy                           0.62      7545
#    macro avg       0.67      0.50      0.39      7545
# weighted avg       0.66      0.62      0.48      7545
#
# ############################################################
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79      1631
#            1       0.64      0.01      0.02       885
#
#     accuracy                           0.65      2516
#    macro avg       0.65      0.50      0.40      2516
# weighted avg       0.65      0.65      0.52      2516

# %% [markdown]
# #### SVM

# %%
from sklearn.svm import SVC

# %%
svm_model= SVC()

# %%
# tuned_parameters = {'C': [0.1,1,10,100],
#                     'gamma': [1, 0.1, 0.01,0.001],
#                     'kernel': ['linear','poly','rbf']}

# %%
# ra_svm=RandomizedSearchCV(svm_model,param_distributions=tuned_parameters,cv = 5, n_jobs = -1,verbose=3)
# ra_svm.fit(x_train, y_train)

# %%
# ra_svm.best_params_

# %%
# best_params_:{'kernel': 'rbf', 'gamma': 1, 'C': 1}

# %%
svm_model.set_params(C=1,gamma=1,kernel='rbf',probability=True)
# Out:
# SVC(C=1, gamma=1, probability=True)

# %%
svm_model.fit(x_train,y_train)
# Out:
# SVC(C=1, gamma=1, probability=True)

# %%
y_pred_test_svm = svm_model.predict(x_test)
y_pred_train_svm = svm_model.predict(x_train)

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_train, y_pred_train_svm)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for training data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_test, y_pred_test_svm)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for testing data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print("Accuracy of training dataset:",accuracy_score(y_train, y_pred_train_svm)*100,'%')
print("Precision of training dataset:",precision_score(y_train, y_pred_train_svm)*100,'%')
print("Recall of training dataset:",recall_score(y_train, y_pred_train_svm)*100,'%')
# Out:
# Accuracy of training dataset: 82.20013253810471 %
# Precision of training dataset: 85.26558891454965 %
# Recall of training dataset: 64.3205574912892 %

# %%
print("Accuracy of training dataset:",accuracy_score(y_test, y_pred_test_svm)*100,'%')
print("Precision of training dataset:",precision_score(y_test, y_pred_test_svm)*100,'%')
print("Recall of training dataset:",recall_score(y_test, y_pred_test_svm)*100,'%')
# Out:
# Accuracy of training dataset: 70.82670906200318 %
# Precision of training dataset: 61.92733017377567 %
# Recall of training dataset: 44.293785310734464 %

# %%
y_pred_test_prob_svm=svm_model.predict_proba(x_test)[::,1]

# %%
fpr_svm, tpr_svm, _ = roc_curve(y_test,  y_pred_test_prob_svm)
auc_svm = roc_auc_score(y_test, y_pred_test_prob_svm)

# %%
plt.plot(fpr_svm,tpr_svm,label="AUC="+str(auc_svm))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
print(classification_report(y_train, y_pred_train_svm))
print("###"*20)
print(classification_report(y_test, y_pred_test_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87      4675
#            1       0.85      0.64      0.73      2870
#
#     accuracy                           0.82      7545
#    macro avg       0.83      0.79      0.80      7545
# weighted avg       0.83      0.82      0.82      7545
#
# ############################################################
#               precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79      1631
#            1       0.62      0.44      0.52       885
#
#     accuracy                           0.71      2516
#    macro avg       0.68      0.65      0.65      2516
# weighted avg       0.70      0.71      0.69      2516

# %% [markdown]
# ### AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ab_model = AdaBoostClassifier()

# %%
# ab_params = {'n_estimators':[10,50,100,200,450,500],
#               'learning_rate':[0.0001,0.001,0.01,0.1,0.2,0.5,1]}

# %%
# ab_grid_cv=GridSearchCV(ab_model,param_grid=ab_params,cv=10,n_jobs=-1)
# ab_grid_cv.fit(x_train,y_train)

# %%
# ab_grid_cv.best_params_

# %%
# best_params_={'learning_rate': 1, 'n_estimators': 500}

# %%
ab_model.set_params(n_estimators=500,learning_rate=1)
# Out:
# AdaBoostClassifier(learning_rate=1, n_estimators=500)

# %%
ab_model.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(learning_rate=1, n_estimators=500)

# %%
ab_importance_cv=ab_model.feature_importances_

# %%
pd.Series(ab_importance_cv,index=x.columns).sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
y_pred_test_ab = ab_model.predict(x_test)
y_pred_train_ab = ab_model.predict(x_train)

# %%
print("Accuracy of training dataset:",accuracy_score(y_train, y_pred_train_ab)*100,'%')
print("Precision of training dataset:",precision_score(y_train, y_pred_train_ab)*100,'%')
print("Recall of training dataset:",recall_score(y_train, y_pred_train_ab)*100,'%')
# Out:
# Accuracy of training dataset: 72.47183565275016 %
# Precision of training dataset: 68.6940122583687 %
# Recall of training dataset: 50.76655052264808 %

# %%
print("Accuracy of training dataset:",accuracy_score(y_test, y_pred_test_ab)*100,'%')
print("Precision of training dataset:",precision_score(y_test, y_pred_test_ab)*100,'%')
print("Recall of training dataset:",recall_score(y_test, y_pred_test_ab)*100,'%')
# Out:
# Accuracy of training dataset: 70.94594594594594 %
# Precision of training dataset: 60.90651558073654 %
# Recall of training dataset: 48.58757062146893 %

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_train, y_pred_train_ab)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for training data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_test, y_pred_test_ab)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for testing data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
y_pred_test_prob_ab=ab_model.predict_proba(x_test)[::,1]

# %%
fpr_ab, tpr_ab, _ = roc_curve(y_test,  y_pred_test_prob_ab)
auc_ab = roc_auc_score(y_test, y_pred_test_prob_ab)

# %%
plt.plot(fpr_ab,tpr_ab,label="AUC="+str(auc_ab))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
print(classification_report(y_train, y_pred_train_ab))
print("###"*20)
print(classification_report(y_test, y_pred_test_ab))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.86      0.79      4675
#            1       0.69      0.51      0.58      2870
#
#     accuracy                           0.72      7545
#    macro avg       0.71      0.68      0.69      7545
# weighted avg       0.72      0.72      0.71      7545
#
# ############################################################
#               precision    recall  f1-score   support
#
#            0       0.75      0.83      0.79      1631
#            1       0.61      0.49      0.54       885
#
#     accuracy                           0.71      2516
#    macro avg       0.68      0.66      0.66      2516
# weighted avg       0.70      0.71      0.70      2516

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBClassifier

# %%
xgb_model = XGBClassifier()

# %%
# xgb_params={
#  "learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.30 ] ,
#  "max_depth"        : [ 3, 4, 5, 6],
#  "min_child_weight" : [ 1, 3, 5, 7 ],
#  "gamma"            : [ 0.1, 0.2 , 0.3, 0.4 ],
#  "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ]}

# %%
# xgb_grid_cv=GridSearchCV(xgb_model,param_grid=xgb_params,cv=10,n_jobs=-1)
# xgb_grid_cv.fit(x_train,y_train)

# %%
# xgb_grid_cv.best_params_

# %%
#  best_params_={'colsample_bytree': 0.7,
#  'gamma': 0.4,
#  'learning_rate': 0.3,
#  'max_depth': 6,
#  'min_child_weight': 1}

# %%
xgb_model.set_params(colsample_bytree=0.7,gamma=0.4,learning_rate=0.3,max_depth=6,min_child_weight=1)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=0.4,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=1, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...)

# %%
xgb_model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.7,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0.4, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.3, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
xgb_importance=ab_model.feature_importances_

# %%
pd.Series(xgb_importance,index=x.columns).sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
y_pred_test_xgb = xgb_model.predict(x_test)
y_pred_train_xgb = xgb_model.predict(x_train)

# %%
print("Accuracy of training dataset:",accuracy_score(y_train, y_pred_train_xgb)*100,'%')
print("Precision of training dataset:",precision_score(y_train, y_pred_train_xgb)*100,'%')
print("Recall of training dataset:",recall_score(y_train, y_pred_train_xgb)*100,'%')
# Out:
# Accuracy of training dataset: 90.3247183565275 %
# Precision of training dataset: 90.99616858237547 %
# Recall of training dataset: 82.75261324041811 %

# %%
print("Accuracy of testing dataset:",accuracy_score(y_test, y_pred_test_xgb)*100,'%')
print("Precision of testing dataset:",precision_score(y_test, y_pred_test_xgb)*100,'%')
print("Recall of testing dataset:",recall_score(y_test, y_pred_test_xgb)*100,'%')
# Out:
# Accuracy of testing dataset: 78.17965023847377 %
# Precision of testing dataset: 72.04724409448819 %
# Recall of testing dataset: 62.03389830508475 %

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_train, y_pred_train_xgb)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for training data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_test, y_pred_test_xgb)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for testing data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
y_pred_test_prob_xgb=ab_model.predict_proba(x_test)[::,1]

# %%
fpr_xgb, tpr_xgb, _ = roc_curve(y_test,  y_pred_test_prob_xgb)
auc_xgb = roc_auc_score(y_test, y_pred_test_prob_xgb)

# %%
plt.plot(fpr_xgb,tpr_xgb,label="AUC="+str(auc_xgb))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
print(classification_report(y_train, y_pred_train_xgb))
print("###"*20)
print(classification_report(y_test, y_pred_test_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92      4675
#            1       0.91      0.83      0.87      2870
#
#     accuracy                           0.90      7545
#    macro avg       0.90      0.89      0.90      7545
# weighted avg       0.90      0.90      0.90      7545
#
# ############################################################
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84      1631
#            1       0.72      0.62      0.67       885
#
#     accuracy                           0.78      2516
#    macro avg       0.76      0.74      0.75      2516
# weighted avg       0.78      0.78      0.78      2516

# %% [markdown]
# ### Stacking Classifier

# %%
from mlxtend.classifier import StackingClassifier

# %%
lr=LogisticRegression()

# %%
clf_stack = StackingClassifier(classifiers =[dt_model, rf_model, knn_model, nb_model, svm_model,ab_model, xgb_model], meta_classifier = lr, use_probas = True, use_features_in_secondary = True)

# %%
stack_model = clf_stack.fit(x_train, y_train)

# %%
y_pred_test_stack = stack_model.predict(x_test)

# %%
y_pred_train_stack = stack_model.predict(x_train)

# %%
print("Accuracy of training dataset:",accuracy_score(y_train, y_pred_train_stack)*100,'%')
print("Precision of training dataset:",precision_score(y_train, y_pred_train_stack)*100,'%')
print("Recall of training dataset:",recall_score(y_train, y_pred_train_stack)*100,'%')
# Out:
# Accuracy of training dataset: 99.56262425447316 %
# Precision of training dataset: 99.54593084177436 %
# Recall of training dataset: 99.30313588850174 %

# %%
print("Accuracy of testing dataset:",accuracy_score(y_test, y_pred_test_stack)*100,'%')
print("Precision of testing dataset:",precision_score(y_test, y_pred_test_stack)*100,'%')
print("Recall of testing dataset:",recall_score(y_test, y_pred_test_stack)*100,'%')
# Out:
# Accuracy of testing dataset: 81.04133545310016 %
# Precision of testing dataset: 78.25484764542936 %
# Recall of testing dataset: 63.84180790960452 %

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_train, y_pred_train_stack)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for training data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix(y_test, y_pred_test_stack)), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix for testing data', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
y_pred_test_prob_stack=stack_model.predict_proba(x_test)[::,1]

# %%
fpr_stack, tpr_stack, _ = roc_curve(y_test,  y_pred_test_prob_stack)
auc_stack = roc_auc_score(y_test, y_pred_test_prob_stack)

# %%
plt.plot(fpr_stack,tpr_stack,label="AUC="+str(auc_stack))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
print(classification_report(y_train, y_pred_train_stack))
print("###"*20)
print(classification_report(y_test, y_pred_test_stack))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4675
#            1       1.00      0.99      0.99      2870
#
#     accuracy                           1.00      7545
#    macro avg       1.00      1.00      1.00      7545
# weighted avg       1.00      1.00      1.00      7545
#
# ############################################################
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      1631
#            1       0.78      0.64      0.70       885
#
#     accuracy                           0.81      2516
#    macro avg       0.80      0.77      0.78      2516
# weighted avg       0.81      0.81      0.81      2516
